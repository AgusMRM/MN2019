# %%
import numpy as np
import matplotlib.pylab as plt

# %%
t0=np.loadtxt('7_alpha-2.dat')
t1=np.loadtxt('7_alpha-1.dat')
t2=np.loadtxt('7_alpha0.dat')
t3=np.loadtxt('7_alpha1.dat')

# %%
plt.plot(t0[:,0],t0[:,1],linestyle='none',marker='.')

# %%
plt.plot(t1[:,0],t1[:,1],linestyle='none',marker='.')

# %%
plt.plot(t2[:,0],t2[:,1],linestyle='none',marker='.')

# %%
plt.plot(t3[:,0],t3[:,1],linestyle='none',marker='.')
