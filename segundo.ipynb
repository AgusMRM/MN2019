# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
osc = np.loadtxt('oscilador.dat')

# %%
plt.plot(osc[:,2],osc[:,0],label='posicion')
plt.plot(osc[:,2],osc[:,1],label='velocidad')
plt.ylabel('solucion')
plt.xlabel('tiempo')
plt.legend()
plt.xlim(0,10)
# Out:
# (0, 10)

# %%
plt.plot(osc[:,2],osc[:,3],label='error energy')
plt.legend()
plt.ylabel('error relativo')
plt.xlim(0,7)
# Out:
# (0, 7)

# %%
plt.plot(osc[:,0],osc[:,1])
plt.xlabel('posicion')
plt.ylabel('velocidad')
plt.title('espacio de fases')
# Out:
# Text(0.5,1,'espacio de fases')
