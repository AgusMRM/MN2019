# %%
import numpy as np
import matplotlib.pylab as plt

# %%
t=np.loadtxt('zeros.dat')

# %%
plt.plot(t[:,2],t[:,0], label='Newton-Rapson')
plt.plot(t[:,2],t[:,1],label='biseccion')
plt.title('Evolucion del error')
plt.xlabel('iteracion')
plt.ylabel('error')
plt.legend()
