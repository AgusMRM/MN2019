# %%
import numpy as np
import matplotlib.pylab as plt

# %%
t2=np.loadtxt('primero_001.dat')
t1=np.loadtxt('primero_01.dat')
t0=np.loadtxt('primero_1.dat')

# %%
fig=plt.figure(figsize=(8,8))
fig.subplots_adjust(bottom=0.08,top=0.98,left=.15,right=.7)

ax1=fig.add_subplot(211)
ax1.plot(t2[:,4],t2[:,0],color='blue',label='adelantada')
ax1.plot(t2[:,4],t2[:,1],color='red',label='atrasada')
ax1.plot(t2[:,4],t2[:,2],color='green',label='centrada')
ax1.legend()

ax2=fig.add_subplot(212)
ax2.plot(t2[:,4],t2[:,5],color='blue',label='adelantada')
ax2.plot(t2[:,4],t2[:,6],color='red',label='atrasada')
ax2.plot(t2[:,4],t2[:,7],color='green',label='centrada')
ax2.legend()

# %%
fig=plt.figure(figsize=(8,8))
fig.subplots_adjust(bottom=0.08,top=0.98,left=.15,right=.7)

ax1=fig.add_subplot(211)
ax1.plot(t1[:,4],t1[:,0],color='blue',label='adelantada')
ax1.plot(t1[:,4],t1[:,1],color='red',label='atrasada')
ax1.plot(t1[:,4],t1[:,2],color='green',label='centrada')
ax1.legend()

ax2=fig.add_subplot(212)
ax2.plot(t1[:,4],t1[:,5],color='blue',label='adelantada')
ax2.plot(t1[:,4],t1[:,6],color='red',label='atrasada')
ax2.plot(t1[:,4],t1[:,7],color='green',label='centrada')
ax2.legend()

# %%
fig=plt.figure(figsize=(8,8))
fig.subplots_adjust(bottom=0.08,top=0.98,left=.15,right=.7)

ax1=fig.add_subplot(211)
ax1.plot(t0[:,4],t0[:,0],color='blue',label='adelantada')
ax1.plot(t0[:,4],t0[:,1],color='red',label='atrasada')
ax1.plot(t0[:,4],t0[:,2],color='green',label='centrada')
ax1.legend()

ax2=fig.add_subplot(212)
ax2.plot(t0[:,4],t0[:,5],color='blue',label='adelantada')
ax2.plot(t0[:,4],t0[:,6],color='red',label='atrasada')
ax2.plot(t0[:,4],t0[:,7],color='green',label='centrada')
ax2.legend()

# %%
# du/dt = u**2

t2=np.loadtxt('primero2_001.dat')
t1=np.loadtxt('primero2_01.dat')
t0=np.loadtxt('primero2_1.dat')

# %%
fig=plt.figure(figsize=(8,8))
fig.subplots_adjust(bottom=0.08,top=0.98,left=.15,right=.7)

ax1=fig.add_subplot(211)
ax1.plot(t0[:,2],t0[:,0],color='blue',label='adelantada')
ax1.plot(t0[:,2],t0[:,0],color='red',label='atrasada')
ax1.plot(t0[:,2],t0[:,0],color='green',label='centrada')
ax1.legend()

ax2=fig.add_subplot(212)
ax2.plot(t0[:,0],t2[:,5],color='blue',label='adelantada')
ax2.plot(t0[:,0],t2[:,6],color='red',label='atrasada')
ax2.plot(t0[:,0],t2[:,7],color='green',label='centrada')
ax2.legend()

# %%
fig=plt.figure(figsize=(8,8))
fig.subplots_adjust(bottom=0.08,top=0.98,left=.15,right=.7)

ax1=fig.add_subplot(211)
ax1.plot(t1[:,4],t1[:,0],color='blue',label='adelantada')
ax1.plot(t1[:,4],t1[:,1],color='red',label='atrasada')
ax1.plot(t1[:,4],t1[:,2],color='green',label='centrada')
ax1.legend()

ax2=fig.add_subplot(212)
ax2.plot(t1[:,4],t1[:,5],color='blue',label='adelantada')
ax2.plot(t1[:,4],t1[:,6],color='red',label='atrasada')
ax2.plot(t1[:,4],t1[:,7],color='green',label='centrada')
ax2.legend()

# %%
fig=plt.figure(figsize=(8,8))
fig.subplots_adjust(bottom=0.08,top=0.98,left=.15,right=.7)

ax1=fig.add_subplot(211)
ax1.plot(t0[:,4],t0[:,0],color='blue',label='adelantada')
ax1.plot(t0[:,4],t0[:,1],color='red',label='atrasada')
ax1.plot(t0[:,4],t0[:,2],color='green',label='centrada')
ax1.legend()

ax2=fig.add_subplot(212)
ax2.plot(t0[:,4],t0[:,5],color='blue',label='adelantada')
ax2.plot(t0[:,4],t0[:,6],color='red',label='atrasada')
ax2.plot(t0[:,4],t0[:,7],color='green',label='centrada')
ax2.legend()
