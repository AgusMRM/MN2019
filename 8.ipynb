# %%
import numpy as np
import matplotlib.pylab as plt

# %%
t=np.loadtxt('ocho.dat')
plt.plot(t[:,0],t[:,1],'.k',markersize=.5)

# %%
t0=np.loadtxt('Galaxy_binporNP.dat')
t1=np.loadtxt('perfilG.dat')

# %%
x=[]
y=[]
Rd=1
for i in np.linspace(0,10,100):
    x.append(i)
    y.append(1500*np.exp(-i/Rd))

# %%
plt.plot(t0[:,1],np.log10(t0[:,0]),label='igual numerp de particulas')
plt.plot(t1[:,0],np.log10(t1[:,1]),label='igual ancho bin')
plt.xlim(0,6)
plt.ylim(0,3)
plt.legend()
