# %%
import numpy as np
import matplotlib.pylab as  plt

# %%
t0=np.loadtxt('pendulo01.dat')
t1=np.loadtxt('pendulo001.dat')
t2=np.loadtxt('pendulo0001.dat')
t3=np.loadtxt('pendulo00001.dat')
t4=np.loadtxt('pendulo000001.dat')

# %%
E0=(t0[:,3]-t0[:,4])/t0[:,4]
E1=(t1[:,3]-t1[:,4])/t1[:,4]
E2=(t2[:,3]-t2[:,4])/t2[:,4]
E3=(t3[:,3]-t3[:,4])/t3[:,4]
E4=(t4[:,3]-t4[:,4])/t4[:,4]

# %%
plt.plot(t0[:,2],t0[:,1],label='v(t)' )
plt.plot(t0[:,2],t0[:,0],label='x(t)')
plt.legend()

# %%
plt.plot(t0[:,2],(t0[:,3]-t0[:,4])/t0[:,4],label='dt=1e-2')
plt.plot(t1[:,2],(t1[:,3]-t1[:,4])/t1[:,4],label='dt=1e-3')

plt.xlabel('time')
plt.ylabel('error relativo')
plt.legend()

# %%
e0=np.max(E0)
e1=np.max(E1)
e2=np.max(E2)
e3=np.max(E3)
e4=np.max(E4)
e5=3.62275951E-02
e6=0.407886475

# %%
e=[e0,e1,e2,e3,e4,e5,e6]
pasos=[.1,.01,.001,.0001,.00001,.0000001,.00000001]

# %%
print e4
# Out:
# 2.1297792476669546e-05

# %%
plt.plot(pasos,e)
plt.semilogx()
plt.xlabel('n pasos')
plt.ylabel('error relativo')
#MORALEJA, no achicar al pedo en paso
# Out:
# Text(0,0.5,'error relativo')
